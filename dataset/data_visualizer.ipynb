# %%
import sys

import numpy as np
from dataset import *

import argparse
import torch

import os

current_script_path = os.getcwd()
main_folder_path = os.path.dirname(current_script_path)

if main_folder_path not in sys.path:
    sys.path.append(main_folder_path)


# sys.path.append('.')
from domains.gridworld import *
from generators.obstacle_gen import *
from dataset import*
# sys.path.remove('.')

train_data = GridworldData(file='gridworld_28x28.npz', imsize=28, train=True)

# Optionally, create another instance for test data
test_data = GridworldData(file='gridworld_28x28.npz', imsize=28, train=False)
# Out:
# Number of Train Samples: 27
# Number of Test Samples: 5

# %%
index = 9
img, s1, s2, label = train_data[index]

if img.ndim == 3 and img.shape[0] == 2: 
    img_to_plot = img[0]  
else:
    img_to_plot = img  

plt.imshow(1-img[0], cmap='gray')  
plt.colorbar()  
plt.scatter(s2, s1, color='red', label=f'Label: {label}')

plt.legend()  # Show the label as a legend
plt.show()

# %%
img_t, s1_t, s2_t, label_t = test_data[0]
if img_t.ndim == 3 and img_t.shape[0] == 2: 
    img_to_plot_t = img_t[0]  
else:
    img_to_plot_t = img_t  

plt.imshow(1-img_t[0], cmap='gray')  
plt.colorbar()  
plt.scatter(s2_t, s1_t, color='red', label=f'Label: {label_t}')

plt.legend()  # Show the label as a legend
plt.show()

# %%
# if isinstance(img, torch.Tensor):
#     img = img.numpy()

# # The image might be in a channel-first format (C, H, W) common in PyTorch datasets.
# # If so, we need to convert it to H, W for plotting.
# if img.shape[0] < img.shape[1]:  # Assuming H, W is the shape with larger dimensions
#     img = img.squeeze()  # Remove the channel dimension if it's single-channel (grayscale)

# Plotting the image
plt.imshow(img)  # Ensure grayscale is used for the colormap
plt.colorbar()  # Optional: Adds a colorbar to the side to indicate scale

# Plotting the point (s2, s1) on the image
# Note the reversal of s1 and s2 since matplotlib plots with (x, y) coordinates
plt.scatter(s2, s1, color='red', label=f'Point ({s2}, {s1})')

plt.title(f'Label: {label}')
plt.legend()  # Show legend
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 10
#       1 # if isinstance(img, torch.Tensor):
#       2 #     img = img.numpy()
#       3
#    (...)
#       8
#       9 # Plotting the image
# ---> 10 plt.imshow(img)  # Ensure grayscale is used for the colormap
#      11 plt.colorbar()  # Optional: Adds a colorbar to the side to indicate scale
#      13 # Plotting the point (s2, s1) on the image
#      14 # Note the reversal of s1 and s2 since matplotlib plots with (x, y) coordinates
#
# File ~/anaconda3/envs/vin/lib/python3.8/site-packages/matplotlib/pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
# ...
